# %%
from transformers import BartForConditionalGeneration, BartTokenizer
from typing import List, Tuple, Any
import nltk
import numpy as np
from tqdm import tqdm
from nltk.tokenize import sent_tokenize
from fastcore.all import *

# %%
utterances = [('speaker 1', "right here we have a machine a big machine a cool tell this machine and it's a time machine and everyone in this room enough to get into it and you can go backwards you can go forward you can not stay where you are I wonder what you choose because of the masking my friends this question a lot lately and they all want to go back I don't wanna go back before there were automobiles or Twitter or American idol I don't know I I'm convinced that there's some sort of pull to the scholarship to wishful thinking and I understand that I'm not part of that crowd I have to say I don't want to go back and it's not because I'm adventurous it's because possibilities on this planet they don't go back to go forward so I want to get in the machine and I want to go forward this is the greatest time there's ever been on this planet by any measure do you wish to choose health well mobility opportunity declining rates of disease there's never been a time like this my great grandparents died all of them by the time they were sixty my grandparents push that number to seventy my parents are closing in on eighty so I the better viewed the better the a nine in the beginning of my death number on but it's not even about people like us because this is a bigger deal than that the kid born in New Delhi today can expect to live as long as the richest man in the world did a hundred years ago think about that it's an incredible fact Eliza true smallpox smallpox killed billions of people on this planet it reshaped the demography of the globe in a way that no war ever house it's gone it's vanished without question in the rich world diseases that threaten millions of us just a generation ago no longer exist hardly rubella doesn't even know what those things are vaccines modern medicine our ability to feed to billions of people those are triumphs of the scientific method into my mind the scientific method trying stuff out see if it works changing it when it doesn't it's one of the great accomplishments of humanity so that's the good news unfortunately that's all the goodness because there's some other problems and they've been mentioned many times and one of them is that despite all accomplishments a billion people go to bed hungry in this world every day that number is rising it's rising really rapidly and it's disgraceful and not only that we've used our imagination to thoroughly trash this glove potable water arable land rain forests oil gas they're going away and they're going away soon unless we innovate our way out of this enough we're going away to so the question is can we do that and I think we can I think it's clear that we can make food that will feed billions of people without raping the land that they live on I think we can power this world with energy that doesn't also destroyed I really do believe that in no in a wishful thinking but here's the thing that keeps me up at night one of the things that keeps me up at night we've never needed progress in science more than we need it right now never and we've also never been in a position to deploy it properly in the way that we can today we're on the verge of amazing amazing events in many fields and yet I actually think we have to go back hundreds three hundred years before the enlightenment to find a time when we battled progress when we thought about these things more vigorously on on more fronts then we do now people wrap themselves in their beliefs and they do it so tightly that you can't set them free not even the truth will set them free listen everyone's entitled to their opinion they're even entitled to their opinion about progress you know you're not entitled to you're not entitled to your own stocks sorry you're not in this took me awhile to figure out about a decade ago I wrote a story about vaccines for The New Yorker a little story and I was amazed to find opposition opposition to what is after all the most effective public health measure in human history I know what to do so I just did what I do I wrote a story I moved on and on soon after that I read a story about genetically engineered food same thing only bigger people were going crazy so I love the story about that too and I couldn't understand why people thought this was Franken foods why they thought moving all kills around in a specific rather than a haphazard way was trust passing on nature's ground but you know I do what I do I wrote the story I moved on I mean I'm a journalist we tried we file we go to dinner it's fun but this story is bothered me and I couldn't figure out why and eventually I did and that's because of those fanatics that were driving me crazy weren't actually fanatics at all they were thoughtful people educated people do some people they were exactly like the people in this room it just disturbs me so much with that I thought you know let's be honest we're at a point in this
# utterances = [('Speaker 2', "Uh huh mary hi hello, I'm Susan Thompson Resource manager. "), ('Speaker 1', "Hi, I'm mary Hanson and I'm applying for one of your kitchen jobs. Great, here's a copy of my resume. "), ('Speaker 2', 'Great, have a seat mary.'), ('Speaker 1', 'Thank you. '), ('Speaker 2', 'Mary, do you have any experience working in the kitchen? '), ('Speaker 1', 'No, but I want to learn, I work hard and I cook a lot at home. '), ('Speaker 2', 'Okay, well tell me about yourself. '), ('Speaker 1', "Well I love to learn new things. I'm very organized and I follow directions. Exactly. That's why my boss at my last job made me a trainer and the company actually gave me a special certificate for coming to work on time every day for a year and I'm taking an english class to improve my writing skills. That's."), ('Speaker 2', 'Great. Why did you leave your last job? '), ('Speaker 1', 'It was graveyard and I need to work days. '), ('Speaker 2', 'Oh I see. Well what hours can you.'), ('Speaker 1', 'Work from eight am until five pm. '), ('Speaker 2', 'Okay well do you have any questions for me mary? '), ('Speaker 1', 'Yes. What kind of training is needed? '), ('Speaker 2', 'Not a lot. Most new workers can learn everything the first day. Do you have any other questions? '), ('Speaker 1', "No, I don't think so, but I've heard a lot of good things about your company and I would really like to work here. "), ('Speaker 2', 'Well I have a few more interviews to do today but I will call you tomorrow if you get the job. Okay, you are sure. Nice to meet you. Nice meeting.'), ('Speaker 1', 'You too. Thank you so much for your time. Yes, good luck. Thank you.')]

# %%
def break_up_long_sentences(sentences: List[str], num_words: int):

    def get_sections(text: str, num_words: int):
        text = text.split()
        result = np.arange(0, len(text), num_words)
        if result[-1] != len(text):
            result = np.append(result, len(text))
        sections = []
        for index in range(len(result) - 1):
            sections.append(
                ' '.join(text[result[index]:result[index + 1]]))
        return sections

    results = []
    for sentence in sentences:
        if len(sentence.split()) >= num_words:
            results.extend(get_sections(sentence, num_words))
        else:
            results.append(sentence)

    return results

# %%
def get_sections_from_texts(texts: Any, num_words: int):
    if isinstance(texts, str):
        all_utterances = sent_tokenize(texts)
        all_speakers = ['' for _ in range(len(all_utterances))]

    else:
        all_speakers, all_utterances = list(zip(*texts))
        all_utterances = list(all_utterances)
        all_speakers = [f'{speaker}: ' for speaker in list(all_speakers)]

    results = []
    section_text = ''
    section_length = 0
    while len(all_utterances):
        utterance = all_utterances[0]
        length = len(utterance.split())
        print(f'Length of the utterance {length}')
        speaker = all_speakers[0]

        if length + section_length < num_words:
            section_text += f'{speaker}{utterance} '
            section_length += length
            all_utterances.pop(0)
            all_speakers.pop(0)

        else:
            last_utterance_sentences = sent_tokenize(utterance)
            last_utterance_sentences = break_up_long_sentences(
                last_utterance_sentences, num_words)
            for sent_index, sent in enumerate(last_utterance_sentences):
                sent_length = len(sent.split())
                print(f'length of the sentence: {sent_length}')
                print(section_length)
                if sent_length + section_length < num_words:
                    if sent_index == 0:
                        section_text += f'{speaker}{sent} '
                    else:
                        section_text += sent
                    section_length += sent_length
                else:
                    results.append(section_text)
                    section_text = ''
                    section_length = 0
                    all_utterances[0] = ' '.join(
                        last_utterance_sentences[sent_index:])
                    break

    if section_text != '':
        results.append(section_text)

    return results

# %%
for index, section in enumerate(get_sections_from_texts(utterances, num_words=900)):
    print(index)
    print(section)
    print(10 * '--')
# Out:
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# Length of the utterance 2863
# length of the sentence: 900
# ...

# %%
for index, section in enumerate(get_sections_from_texts(' '.join([text for _, text in utterances * 10]), num_words=900)):
    print(index)
    print(section)
    print(10 * '--')
# Out:
# 0
# ...

# %%
def get_bart_keywords_openai(utterances: List[Tuple[str, str]], debug: bool = False):
    model = BartForConditionalGeneration.from_pretrained(
        "philschmid/bart-large-cnn-samsum")
    tokenizer = BartTokenizer.from_pretrained(
        "philschmid/bart-large-cnn-samsum"
    )
    cnt = 0
    values = list(tokenizer.decoder.values())

    nltk_tokenizer = nltk.RegexpTokenizer(r"\w+")
    words_in_utterances = nltk_tokenizer.tokenize(
        ' '.join([text for _, text in utterances])
    )
    speaker_in_utterances = nltk_tokenizer.tokenize(
        ' '.join([speaker for speaker, _ in utterances])
    )
    filtered_values = [
        word for word in values if (word not in words_in_utterances) and (word not in speaker_in_utterances)
    ]
    bad_words_ids = [tokenizer.encode(
        bad_word, add_prefix_space=True) for bad_word in filtered_values]

    output = ''
    while True:
        if cnt == 1:
            model = BartForConditionalGeneration.from_pretrained('sshleifer/distilbart-cnn-12-6')
            tokenizer = BartTokenizer.from_pretrained('sshleifer/distilbart-cnn-12-6')
        results = []
        sections_to_process = get_sections_from_texts(
            utterances, 900)
        print(sections_to_process)
        for section in tqdm(sections_to_process, leave=False):
            inputs = tokenizer(
                [section], max_length=1024,
                return_tensors='pt', truncation=True
            )
            summary_ids = model.generate(
                inputs['input_ids'],
                bad_words_ids=bad_words_ids
            )
            results.append(
                tokenizer.decode(
                    summary_ids[0],
                    skip_special_tokens=True,
                    clean_up_tokenization_spaces=False
                )
            )
        output += 'Round {}'.format(cnt) + '\n'
        output += '. '.join(results)
        print('----' * 10)
        output += '\n'
        print(output)
        if len(sections_to_process) == 1:
            return output if debug else '. '.join(results)
        else:
            utterances = '. '.join(results)
        cnt += 1

# %%
summary = get_bart_keywords_openai(utterances * 10)
# Out:
# ["Speaker 2: Uh huh mary hi hello, I'm Susan Thompson Resource manager.  Speaker 1: Hi, I'm mary Hanson and I'm applying for one of your kitchen jobs. Great, here's a copy of my resume.  Speaker 2: Great, have a seat mary. Speaker 1: Thank you.  Speaker 2: Mary, do you have any experience working in the kitchen?  Speaker 1: No, but I want to learn, I work hard and I cook a lot at home.  Speaker 2: Okay, well tell me about yourself.  Speaker 1: Well I love to learn new things. I'm very organized and I follow directions. Exactly. That's why my boss at my last job made me a trainer and the company actually gave me a special certificate for coming to work on time every day for a year and I'm taking an english class to improve my writing skills. That's. Speaker 2: Great. Why did you leave your last job?  Speaker 1: It was graveyard and I need to work days.  Speaker 2: Oh I see. Well what hours can you. Speaker 1: Work from eight am until five pm.  Speaker 2: Okay well do you have any ques
# ...
